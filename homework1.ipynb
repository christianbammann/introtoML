# %% [markdown]
# <a href="https://colab.research.google.com/github/christianbammann/introtoML/blob/main/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/D3.csv")
df.head(5)
# Out:
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]
y = df.values[:, 3]
m = len(y)

# %%
print('x1[:5] =', x1[:5])
print('x2[:5] =', x2[:5])
print('x3[:5] =', x3[:5])
print('y[:5]  =', y[:5])

print('m =', m)
# Out:
# x1[:5] = [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# x2[:5] = [3.44       0.1349495  0.82989899 1.52484848 2.21979798]
# x3[:5] = [0.44       0.88848485 1.3369697  1.78545454 2.23393939]
# y[:5]  = [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m = 100

# %%
plt.figure(figsize=(4, 3))
plt.scatter(x1, y, color='red', marker='.')
plt.grid(True)
plt.xlabel('x1')
plt.ylabel('Y')
plt.title('Scatter: x1 vs Y')
plt.show()

# %%
X_0 = np.ones((m, 1))
X_0[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_1 = x1.reshape(m, 1)
X_1[:5]
# Out:
# array([[0.        ],
#        [0.04040404],
#        [0.08080808],
#        [0.12121212],
#        [0.16161616]])

# %%
X = np.hstack((X_0, X_1))
X[:5]
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616]])

# %%
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
def compute_cost(X, y, theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

# %%
cost = compute_cost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242

# %%
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.T.dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)
    return theta, cost_history

# %%
alpha = 0.05
iterations = 500

# %%
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
# print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 5.90572164 -2.02968566]

# %%
# Assuming that X, y, and theta are already defined
# Also assuming that X has two columns: a feature column and a column of ones

# Scatter plot for the training data
plt.scatter(X[:, 1], y, color='red', marker='.', label='Training Data')

# Line plot for the linear regression model
plt.plot(X[:, 1], X.dot(theta), color='blue', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()
J_x1 = cost_history[-1]
print("Final loss for x1:", J_x1)
# Out:
# Final loss for x1: 0.9850561128289671

# %%
X_0 = np.ones((m, 1))
X_1 = x2.reshape(m, 1)
X = np.hstack((X_0, X_1))
theta = np.zeros(2)
alpha = 0.05
iterations = 500
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)

# %%
plt.scatter(X[:, 1], y, color='red', marker='.', label='Training Data')

plt.plot(X[:, 1], X.dot(theta), color='blue', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

plt.show()

# %%
J_x2 = cost_history[-1]
print("Final loss for x2:", J_x2)
# Out:
# Final loss for x2: 3.5993663941840937

# %%
X_0 = np.ones((m, 1))
X_1 = x3.reshape(m, 1)
X = np.hstack((X_0, X_1))
theta = np.zeros(2)
alpha = 0.05
iterations = 500
theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)

# %%
plt.scatter(X[:, 1], y, color='red', marker='.', label='Training Data')

plt.plot(X[:, 1], X.dot(theta), color='blue', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Linear Regression Fit')
plt.legend()

plt.show()

# %%
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

plt.show()

J_x3 = cost_history[-1]
print("Final loss for x3:", J_x3)
# Out:
# Final loss for x3: 3.629462455099136

# %%
print("x1 final loss:", J_x1)
print("x2 final loss:", J_x2)
print("x3 final loss:", J_x3)
print("Lowest final loss: x1 =", J_x1)
# Out:
# x1 final loss: 0.9850561128289671
# x2 final loss: 3.5993663941840937
# x3 final loss: 3.629462455099136
# Lowest final loss: x1 = 0.9850561128289671

# %%
# x1
X = np.hstack((np.ones((m,1)), x1.reshape(m,1)))
theta = np.zeros(2)
theta, cost_history = gradient_descent(X, y, theta, 0.05, 500)
print(f"x1: y = {theta[0]:.4f} + {theta[1]:.4f} * x1")

# x2
X = np.hstack((np.ones((m,1)), x2.reshape(m,1)))
theta = np.zeros(2)
theta, cost_history = gradient_descent(X, y, theta, 0.05, 500)
print(f"x2: y = {theta[0]:.4f} + {theta[1]:.4f} * x2")

# x3
X = np.hstack((np.ones((m,1)), x3.reshape(m,1)))
theta = np.zeros(2)
theta, cost_history = gradient_descent(X, y, theta, 0.05, 500)
print(f"x3: y = {theta[0]:.4f} + {theta[1]:.4f} * x3")
# Out:
# x1: y = 5.9057 + -2.0297 * x1
# x2: y = 0.7343 + 0.5583 * x2
# x3: y = 2.8621 + -0.5168 * x3

# %%
for a in [0.1, 0.05, 0.01]:
    X = np.hstack((np.ones((m,1)), x1.reshape(m,1)))
    theta = np.zeros(2)
    theta, hist = gradient_descent(X, y, theta, a, 500)
    print(f"x1 with alpha={a}: final loss = {hist[-1]:.6f}")
# Out:
# x1 with alpha=0.1: final loss = 0.984993
# x1 with alpha=0.05: final loss = 0.985056
# x1 with alpha=0.01: final loss = 1.457869

# %%
for a in [0.1, 0.05, 0.01]:
    X = np.hstack((np.ones((m,1)), x2.reshape(m,1)))
    theta = np.zeros(2)
    theta, hist = gradient_descent(X, y, theta, a, 500)
    print(f"x1 with alpha={a}: final loss = {hist[-1]:.6f}")
# Out:
# x1 with alpha=0.1: final loss = 3.599366
# x1 with alpha=0.05: final loss = 3.599366
# x1 with alpha=0.01: final loss = 3.602186

# %%
for a in [0.1, 0.05, 0.01]:
    X = np.hstack((np.ones((m,1)), x3.reshape(m,1)))
    theta = np.zeros(2)
    theta, hist = gradient_descent(X, y, theta, a, 500)
    print(f"x1 with alpha={a}: final loss = {hist[-1]:.6f}")
# Out:
# x1 with alpha=0.1: final loss = 3.629451
# x1 with alpha=0.05: final loss = 3.629462
# x1 with alpha=0.01: final loss = 3.726394

# %%
# Problem 2
m = len(y)
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)
X = np.hstack((X_0, X_1, X_2, X_3))

# %%
theta = np.zeros(4)
alphas = [0.1, 0.05, 0.01]
iterations = 500

# %%
best_J = float('inf')
best = None

# %%
for a in alphas:
    theta0 = np.zeros(4)
    th, hist = gradient_descent(X, y, theta0, a, iterations)
    J = hist[-1]
    print(f"alpha={a}: final J={J:.6f},  y = {th[0]:.4f} + {th[1]:.4f}*x1 + {th[2]:.4f}*x2 + {th[3]:.4f}*x3")

    if J < best_J:
        best_J = J
        best = {"alpha": a, "theta": th, "history": hist}

print("\nBest:")
print(f"alpha={best['alpha']}, final J={best_J:.6f}")
print(f"y = {best['theta'][0]:.4f} + {best['theta'][1]:.4f}*x1 + {best['theta'][2]:.4f}*x2 + {best['theta'][3]:.4f}*x3")
# Out:
# alpha=0.1: final J=0.738528,  y = 5.2795 + -1.9988*x1 + 0.5383*x2 + -0.2605*x3
# alpha=0.05: final J=0.748170,  y = 4.8873 + -1.9434*x1 + 0.6031*x2 + -0.2030*x3
# alpha=0.01: final J=1.267988,  y = 2.1613 + -1.5555*x1 + 1.0526*x2 + 0.1947*x3
#
# Best:
# alpha=0.1, final J=0.738528
# y = 5.2795 + -1.9988*x1 + 0.5383*x2 + -0.2605*x3

# %%
plt.plot(range(1, len(best["history"]) + 1), best["history"])
plt.grid(True); plt.xlabel("Iteration"); plt.ylabel("Cost (J)")
plt.title(f"Convergence (alpha={best['alpha']})")
plt.show()

# %%
# Predictions
b = best["theta"]

def predict_row(x1v, x2v, x3v):
    return float(b[0] + b[1]*x1v + b[2]*x2v + b[3]*x3v)

print("(1,1,1) =", predict_row(1, 1, 1))
print("(2,0,4) =", predict_row(2, 0, 4))
print("(3,2,1) =", predict_row(3, 2, 1))
# Out:
# (1,1,1) = 3.5584537970170693
# (2,0,4) = 0.23977565356263764
# (3,2,1) = 0.09909827944161465
